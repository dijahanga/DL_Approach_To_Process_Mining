# %% [markdown]
# <a href="https://colab.research.google.com/github/dijahanga/DL_Approach_To_Process_Mining/blob/main/MeanDelay_PGraphDD_SS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import graphviz
import math
import numpy as np
import random
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from matplotlib import pyplot as plt
from keras.models import load_model
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import KFold
from keras.layers import Dropout
from keras.preprocessing.sequence import pad_sequences
from keras.utils.vis_utils import plot_model
import pydotplus as pydot
from graphviz import Digraph
import copy
import csv
from google.colab import files
from collections import namedtuple

# %%
class dataDivider:
  def __init__(self, data):
    self.data = data
    self.tracesPerPart = 0
    self.totalCount = 0
  def getPartDictionary(self, labels):
    indexes = []
    _activeCase = None
    caseLabel = labels.case;
    indexi = []
    index = 0
    for index, row in self.data.iterrows():
      if (_activeCase == None):
        _activeCase = row[caseLabel]
        indexi = [index, -1]
      else:
        if (_activeCase != row[caseLabel]):
          indexi[1] = index
          indexes.append(tuple(indexi))
          indexi[0] = index + 1
          _activeCase = row[caseLabel]
    indexi[1] = index + 1
    indexes.append(tuple(indexi))
    return indexes
  def setParts(self, labels, parts):
    indexes = self.getPartDictionary(labels)
    if parts > len(indexes):
      raise ValueError('Part cannot be greater than total events') 
    approxSize = round(len(indexes)/parts)
    partIndexes = []
    partIndexesSeries = []
    partCount = []
    for i in range(0, parts):
      top = i * approxSize
      bottom = top + approxSize -1
      startIndex = indexes[top][0]
      if len(indexes) <= bottom:
        bottom = len(indexes) - 1
      endIndex = indexes[bottom][1];
      series = indexes[top:bottom+1]      
      partIndexes.append([startIndex, endIndex])
      partIndexesSeries.append(series)
      partCount.append(approxSize)
    self.partIndexes = partIndexes
    self.totalCount = len(indexes)
    self.tracesPerPart = approxSize
    self.partIndexesSeries = partIndexesSeries
    return partIndexes
  def getPartIndex(self, indx):
    return self.data.iloc[self.partIndexes[indx][0]], self.data.iloc[self.partIndexes[indx][1]];
  def getPart(self, index, percentage = 100):
    if(percentage == 100):
      return self.data.iloc[self.partIndexes[index][0]:self.partIndexes[index][1], :]
    thisSeries = self.partIndexesSeries[index]
    count = round((percentage/100) * len(thisSeries));
    topIndex = thisSeries[0][0];
    bottomIndex = thisSeries[count+1][1]
    return self.data.iloc[topIndex:bottomIndex, :]

# %%
class prepareData:
  def __init__(self, data, label):
    self.data = data
    self.label = label
  def create_input_output(self, xy):
    # Define Empty List
    values = []
    xList = []
    _ncols = ('X', 'Y')
    values.append(("NULL", xy[0]))
    i = 0
    while i < len(xy):
        try:
            xList = xy[0: i+1]
            xList.insert(0, "NULL")
            values.append((xList, xy[i + 1]))
        except:
            xList = xy[0: i+1]
            xList.insert(0, "NULL")
            values.append((xList, "END"))
        i = i + 1
    return pd.DataFrame(values, columns=_ncols) 

  def prepare(self, validEvts = None, test_size = 0, tokenizer = None):
    nameLabel = self.label[0]
    valueLabel = self.label[1]
    _activeCase = "NULL"
    _tempxy = []
    _ncols = ('X', 'Y')
    maindfObj = pd.DataFrame([], columns=_ncols)
    if validEvts is not None:
      helperObj = helper()
      validEvts = helperObj.oneDimStrToLower(validEvts)
    for index, row in self.data.iterrows():
      if validEvts is not None and row[valueLabel].lower() not in validEvts:
        continue
      if nameLabel in row and (row[nameLabel] == _activeCase or _activeCase == "NULL"):
        concatenatedString = row[valueLabel]
        _tempxy.append(concatenatedString)
        _activeCase = row[nameLabel]
      else:
        subObject = self.create_input_output(_tempxy)
        maindfObj = maindfObj.append(subObject)
        _activeCase = row[nameLabel]
        _tempxy.clear()
        concatenatedString = row[valueLabel]
        _tempxy.append(concatenatedString)
    self.tokenize(maindfObj, tokenizer)
    self.maindfObj = maindfObj
    return self.custom_split(self.X, self.Y, test_size)

  def append_to_2d(self, former_2d, new_2d):
    for i in range(len(new_2d)):
      former_2d.append(new_2d[i])
    return former_2d

  def custom_split(self, X, Y, test_size):
    Xtrain = []
    Ytrain = []
    Xtest = []
    Ytest = []
    size = X.shape  
    import random
    startList = []
    endList = []
    for i in range(size[0]):
      consid = X[i]
      if consid[len(consid) - 2] == 0:
        startList.append(i)
        if(i > 0):
          endList.append(i-1)
    endList.append(size[0]-1) #Tail End of the Array is the last element of endList
    num_test = int(round(len(startList)*test_size))  
    num_train = len(startList) - num_test    
    t = random.sample(startList, num_test)
    counter = 0
    for i in startList:
      Xcase = np.array(X[i:endList[counter]+1])
      Ycase = np.array(Y[i:endList[counter]+1])
      if (i in t):
        Xtest = self.append_to_2d(Xtest, Xcase)
        Ytest = self.append_to_2d(Ytest, Ycase)
      else:
        Xtrain = self.append_to_2d(Xtrain, Xcase)
        Ytrain = self.append_to_2d(Ytrain, Ycase)
      counter = counter + 1
    return np.array(Xtrain), np.array(Xtest), np.array(Ytrain), np.array(Ytest)

  def tokenize(self, data, tokenizer):
    if tokenizer is None:
      tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n')
      tokenizer.fit_on_texts(data['X'])
    X = tokenizer.texts_to_sequences(data['X'])
    word_index = tokenizer.word_index
    X = pad_sequences(X)
    Y = pd.get_dummies(data['Y'])
    self.X = X
    self.Y = Y
    self.tokenizer = tokenizer

# %%
class helper:
  def __init__(self):
    self.i= 0
  def datasetListMergeMinus(self, dataset, subset):
    wholeData = 1
    for m in dataset:
      if not m.equals(subset):
        if type(wholeData) is int:
          wholeData = m          
        else:
          wholeData = wholeData.append(m)
    return wholeData
  def multiDimStrToUpper(self, string):
    nstring = []
    for strns in string:
      nstring.append([x.upper() for x in strns])
    return nstring
  def multiDimStrToLower(self, string):
    nstring = []
    for strns in string:
      nstring.append([x.lower() for x in strns])
    return nstring
  def oneDimStrToLower(self, string):
    nstring = []
    for i in range(0, len(string)):
      nstring.append(string[i].lower())
    return nstring
  def grabEventsFromHeader(self, header):
    evs = []
    c = 0
    for ev in header:
      if c > 0:
        try:
          num = int(ev)
        except:
          evs.append(ev)
      c = c + 1
    return evs

  def rowIsFirst(self, row, activities, headers):
    foundValues = []
    for i in range(0,len(headers)):
      val = headers[i]
      if row[val] in activities:
        foundValues.append(row[val])
    if (len(foundValues) == 0):
      return True
    return False

  def rowIsLast(self, row, evName):
    rowEv = row.idxmax()
    try:
      if rowEv.lower() == evName.lower():
        return True
    except:
      return False
    return False

  def divideMatrix(self, matrix):
    headers = list(matrix.columns.values)
    leftHeaders = []
    rightHeaders = []
    for i in range(0,len(headers)):
      ev = headers[i]
      try:
          num = int(ev)        
          leftHeaders.append(ev)        
      except:
          rightHeaders.append(ev)
    leftData = matrix[leftHeaders]
    rightData = matrix[rightHeaders]
    return [leftData, rightData]

# %%
class training:
  def __init__(self, X, Y):
    self.X = X
    self.Y = Y
    MAX_NB_WORDS =50   #50
    EMBEDDING_DIM =50   #32
    model = Sequential()
    model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2, recurrent_activation='sigmoid'))
    model.add(Dense(Y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    self.model = model
  def train(self, tindx = '0'):
    model = self.model
    #model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    #print('Training...')
    X = self.X
    Y = self.Y
    history = model.fit(X, Y, epochs=10, batch_size=50, verbose=0)
    self.model = model
    model.save('Orig_model_'+tindx+'.h5')
    return model.evaluate(X, Y)

  def getModelFrom(self, modelprefix):
    try:
      modelName = 'Orig_model_'+modelprefix+'.h5';
      self.model = load_model(modelName)
    except:
      self.train(modelprefix)

  def align(self, from_, to_):
    originalColumnNamesArr = to_.columns.values
    driftedColumnNamesArr = from_.columns.values
    colNum = []
    for i in range(0, len(driftedColumnNamesArr)):
      col = driftedColumnNamesArr[i]
      if(col not in originalColumnNamesArr):
        from_ = from_.drop(col, 1)
        colNum.append(i)
    for i in range(0, len(originalColumnNamesArr)):
      col = originalColumnNamesArr[i]
      if(col not in driftedColumnNamesArr):
        from_[col] = 0
    return from_, colNum

  def validateModel(self, Prep_data, tokenizer, model,  X, Y):
    try:
      predict_proba = model.predict(X)
    except:
      model.summary()
      raise ValueError('Error occured!')
    colName = []
    for i in Y:
        colName.append(i)
    dfObj = pd.DataFrame(list(np.round(predict_proba*100, decimals=0)), columns = colName)
    Seq_Series=Prep_data.X.apply(pd.Series)
    dfObj.reset_index(drop=True, inplace=True)
    Seq_Series.reset_index(drop=True, inplace=True)
    df_new = pd.concat([Seq_Series, dfObj], axis=1)
    return df_new

# %%
class resultGraphing:
  def __init__(self):
    self.i= 0
  def decomposeResult(self, results):
    helper_ = helper()
    headers = list(results.columns.values)
    events = helper_.grabEventsFromHeader(headers)
    matrices = []
    matricesLeft = []
    lastIndex = 0
    totalBegin = 0
    ind = 0
    newMatrix = helper_.divideMatrix(results)
    for index, row in newMatrix[1].iterrows():
      ind = index
      rowIsLast = helper_.rowIsLast(row, "end")
      if rowIsLast:
        sequenceList = newMatrix[1].iloc[lastIndex:index+1, :]
        sequenceListLeft = newMatrix[0].iloc[lastIndex:index+1, :]
        matrices.append(sequenceList)
        matricesLeft.append(sequenceListLeft)
        lastIndex = index + 1
    return matrices, matricesLeft

  def rowIsAnewSequence(self, row):
    try:
      return math.isnan(row["1"])
    except:
      return False

  def linkAndProbabilities(self, matrices, count = 0):
    links = []
    probabilities = []
    sequences = []
    uniqueEvs = []
    for i in range(0,len(matrices)):
      thisMatrix = matrices[i]
      lastEvent = "Start"
      sequence = []
      for index, row in thisMatrix.iterrows():
        row = pd.to_numeric(row)
        evName = row.idxmax(axis=0) # picks event with the highest probability
        link = lastEvent + "<-->" + evName
        sequence.append(evName)
        if link not in links:
          if lastEvent != evName:
            if not (lastEvent.lower() == "start" and evName.lower() == "end"):
              links.append(link)
              prob = row[evName]
              probabilities.append(prob)
        lastEvent = evName
      # The Last element is End and undesirable
      sequence.pop()
      sequences.append(sequence)
    return links, probabilities, sequences

  def linkAndProbabilities_2(self, seqs, probs):
    links = []
    probabilities = []
    sequences = []
    for i in range(0,len(probs)):
      lastEvent = "Start"
      sequence = []
      considprob = probs[i]
      cols = considprob.columns.values
      for index, row in considprob.iterrows():
        evName = row.idxmax()
        link = lastEvent + "<-->" + evName
        sequence.append(evName)
        prob = considprob[evName].max(axis=0)
        if link not in links:
          links.append(link)            
          probabilities.append(prob)              
        lastEvent = evName
      sequence.pop() #
      sequences.append(sequence)
    return links, probabilities, sequences

  def drawGraph(self, transitions, probabilities, fileName = ''):
    G = Digraph('process_model', filename=fileName+'.gv')
    G.attr(rankdir='TB', size='7,5')
    G.attr('node', shape='doublecircle', style="filled", fillcolor="grey")
    G.node('Start')
    G.node('END')
    G.attr('node', shape='box', style="bold")
    for i in range(0,len(transitions)):
      G.attr('edge', style="bold", penwidth='3.0', label=str(probabilities[i]))
      fromto = transitions[i].split("<-->")
      G.edge(fromto[0], fromto[1])
    G.view()
    return G
  
  def getEventSequence(self, data, X_label, Y_label):
    currentX_label = ''
    sequences = []
    sequence = []
    for index, row in data.iterrows():
      if currentX_label == row[X_label]:
        sequence.append(row[Y_label])
      else:
        if len(sequence) > 1:
          sequences.append(sequence)
        sequence = []
        sequence.append(row[Y_label])
      currentX_label = row[X_label]
    sequences.append(sequence)
    return sequences

# %%
class performance:
  def __init__(self):
    self.i= 0
  def getM(self, a, b):
    M = 0
    _index = 0
    for index, row in a.iterrows():
      columnVal = 0
      for cell in row:
        lCell = b.iloc[_index][columnVal]
        if(lCell > 0 or cell > 0):
          M = M + 1
        columnVal = columnVal + 1
      _index = _index + 1
    return M

  def getMatrix(self, chainTable, uniqueEV, testEvents):
    global dfObjio
    event_size = len(uniqueEV)
    matrix = np.zeros((event_size, event_size))
    counter = 0
    for strings in chainTable[0]:
      evs = strings.split("<-->")
      if "Start" in evs:
        continue
      if testEvents is None or (evs[0] in testEvents and evs[1] in testEvents):
        probability = chainTable[1][counter]
        if probability > 1:
          probability = probability/100
        col = uniqueEV.index(evs[0])
        rw = uniqueEV.index(evs[1])
        # if probability < threshold:
        #   probability = 0
        matrix[col, rw] = probability      
        dfObjio = pd.DataFrame(matrix, index=uniqueEV, columns = uniqueEV)
      counter = counter + 1
    return dfObjio
      
      
  def getAdjacency(self, matrixOne, matrixTwo, eventCount):  
    M = self.getM(matrixOne, matrixTwo)
    #case 1 Probability
    absoluteVal = matrixOne.subtract(matrixTwo)
    sumVal = absoluteVal.abs().sum().sum()
    #case 2 Logicals
    matrixOnelg = matrixOne.apply(np.ceil)
    matrixTwolg = matrixTwo.apply(np.ceil)
    absoluteVal = matrixOnelg.subtract(matrixTwolg)
    sumValLogical = absoluteVal.abs().sum().sum()
    #Estimate adjacency
    #print(M)
    #print(sumVal)
    #print(sumValLogical)
    a = 1- sumVal/M
    b = 1- sumValLogical/M
    return [a, b]

# %%
class DatasetDefinitions:
  def getUnique(self, label, dataset):
    chains = []
    chainTag = []
    lastActivity = None
    lastCase = None
    eventLabel = label.event
    caseLabel = label.case
    for index, row in dataset.iterrows():
      if lastCase is None or lastCase != row[caseLabel]:
        lastActivity = None
      if lastActivity is None:
        lastActivity = row[eventLabel]
        lastCase = row[caseLabel]
        continue
      lastCase = row[caseLabel]
      if lastActivity != row[eventLabel]:
        evChain = lastActivity +""+row[eventLabel]
        evChain = evChain.lower().strip()
        evChain = " ".join(evChain.split()).replace(' ', '_')
        if evChain not in chains:
          chains.append(evChain)
          chainTag.append(lastCase)
      lastActivity = row[eventLabel]
    return chains, chainTag

# %%
labels = namedtuple("labels", "case event")
label = labels('case', 'event')

# %%
parts = 75
dataset = pd.read_csv('sw-7500.csv', low_memory= False)
data_divider = dataDivider(dataset)
p_ = data_divider.setParts(label, parts)

# %%
import csv
from google.colab import files

# %%
from numpy.lib.function_base import i0
class DriftWindowManager:
  def __init__(self, data_divider, batchSize = 10):
    self.data_divider = data_divider
    self.batchSize = batchSize
    self.verboseResult = ""
  def worker(self, startWindow, endWindow, referencePerc, detectionPerc, scoreLog = [], threshold = None):
    if(threshold is None):
      if(detectionPerc < 10):
        return scoreLog
    else:
      if(detectionPerc < self.batchSize):
        return scoreLog
    offsetPercentage = 100 - detectionPerc
    referenceLog = self.data_divider.getPart(startWindow, referencePerc)
    detectionLog = self.data_divider.getPart(startWindow, detectionPerc)    
    if(offsetPercentage > 0):
      detectionLog0 = self.data_divider.getPart(endWindow, offsetPercentage)
      detectionLog = pd.concat([detectionLog, detectionLog0])
    modelLabel = str(startWindow)+str(detectionPerc)
    smscore = self.trainer(modelLabel, referenceLog, detectionLog)
    scoreLog.append(smscore)
    if(threshold is not None):
      if (smscore <= threshold):
        return scoreLog
    return self.worker(startWindow, endWindow, referencePerc, detectionPerc - self.batchSize, scoreLog, threshold)
  def run(self, parts, threshold = None):
    logs = []
    for i in range(0, parts):
      j = i + 1
      if(i == parts - 1):
        j = 0
      adjacencies = self.worker(i, j, 100, 100 - self.batchSize, [], threshold)
      logs.append(adjacencies)
      minScore = min(adjacencies)
      mcalc = (self.batchSize * (adjacencies.index(minScore) + 1))
      vresult = '''====================================================
      Reference Window {stri} Detection Window {strj}
      Min. Adjacency: {minScore} After: {mcalc}% in Detection
      Complete Result: {result}
      '''.format(stri=str(i), strj = str(j), minScore = str(minScore), mcalc = str(mcalc), result = str(adjacencies))
      self.verboseResult = self.verboseResult + vresult
      print(vresult)
    return logs

  def trainer(self, window, referenceLog, detectionLog):
    #Prepare the data Reference
    prepdata = prepareData(referenceLog, ['case', 'event'])
    X_train, X_test, Y_train, Y_test = prepdata.prepare(None, 0)

    #get built tokenizer and word_index
    tokenizer = prepdata.tokenizer
    X = prepdata.X
    Y = prepdata.Y
    X_O = X
    Y_O = Y
    v = tokenizer.word_index.keys()

    #Prepare the data Detection
    prepdata_t = prepareData(detectionLog, ['case', 'event'])
    X_train_t, X_test_t, Y_train_t, Y_test_t = prepdata_t.prepare(list(v), 0, tokenizer) #list(v)  
    tokenizer_t = prepdata_t.tokenizer
    X_t = prepdata_t.X
    Y_t = prepdata_t.Y
    X_T = X_t
    Y_T = Y_t

    r = str(window)+"_0"
    r2 = str(window)+"_1"
    #Train the Models
    trainModel_O = training(X_train, Y_train)
    trainModel_O.getModelFrom(r)
    trainModel_T = training(X_train_t, Y_train_t)
    trainModel_T.getModelFrom(r2)      
    #Use on their dataset
    resultDataset_O = trainModel_O.validateModel(prepdata.maindfObj, tokenizer, trainModel_O.model,  X, Y)    
    resultDataset_T = trainModel_T.validateModel(prepdata_t.maindfObj, tokenizer_t, trainModel_T.model,  X_t, Y_t)
    
    #Result graphing
    resultGraphing_ = resultGraphing()
    #Reference
    probs_O, seqs_O = resultGraphing_.decomposeResult(resultDataset_O)
    link_O, probabilities_O, sequences_O = resultGraphing_.linkAndProbabilities(probs_O)
    resultGraphing_.drawGraph(link_O, probabilities_O, r)
    #Adjc log
    probs_T, seqs_T = resultGraphing_.decomposeResult(resultDataset_T)
    link_T, probabilities_T, sequences_T = resultGraphing_.linkAndProbabilities(probs_T)
    resultGraphing_.drawGraph(link_T, probabilities_T, r2)
    perf = performance() 
    h1 = h2 = None
    if len(Y_O.columns.values) > len(Y_T.columns.values): 
      events = list(Y_T.columns.values)
      h1 = perf.getMatrix([link_T, probabilities_T], events, None)
      h2 = perf.getMatrix([link_O, probabilities_O], list(Y_O.columns.values), events)
    else:
      events = list(Y_O.columns.values)
      h1 = perf.getMatrix([link_O, probabilities_O], events, None)
      h2 = perf.getMatrix([link_T, probabilities_T], list(Y_T.columns.values), events)
    result = perf.getAdjacency(h1, h2, len(events))
    #print(result[1])
    return result[1]

# %%
drftmngr = DriftWindowManager(data_divider)
results = drftmngr.run(parts, 0.8)
print(drftmngr.verboseResult)
# Out:
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4246 - accuracy: 0.8700
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4266 - accuracy: 0.8721
# ====================================================
#       Reference Window 0 Detection Window 1
#       Min. Adjacency: 0.75 After: 10% in Detection
#       Complete Result: [0.75]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4778 - accuracy: 0.8588
# 45/45 [==============================] - 1s 6ms/step - loss: 0.3915 - accuracy: 0.8418
# ====================================================
#       Reference Window 1 Detection Window 2
#       Min. Adjacency: 0.5666666666666667 After: 10% in Detection
#       Complete Result: [0.5666666666666667]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4607 - accuracy: 0.8597
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4706 - accuracy: 0.8472
# ====================================================
#       Reference Window 2 Detection Window 3
#       Min. Adjacency: 0.46875 After: 10% in Detection
#       Complete Result: [0.46875]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4562 - accuracy: 0.8768
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4296 - accuracy: 0.8641
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4375 - accuracy: 0.8760
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4758 - accuracy: 0.8700
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4915 - accuracy: 0.8545
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4347 - accuracy: 0.8652
# ====================================================
#       Reference Window 3 Detection Window 4
#       Min. Adjacency: 0.6666666666666667 After: 30% in Detection
#       Complete Result: [0.8461538461538461, 0.92, 0.6666666666666667]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4660 - accuracy: 0.8592
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4329 - accuracy: 0.8680
# ====================================================
#       Reference Window 4 Detection Window 5
#       Min. Adjacency: 0.6875 After: 10% in Detection
#       Complete Result: [0.6875]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4550 - accuracy: 0.8543
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4232 - accuracy: 0.8624
# ====================================================
#       Reference Window 5 Detection Window 6
#       Min. Adjacency: 0.5555555555555556 After: 10% in Detection
#       Complete Result: [0.5555555555555556]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4688 - accuracy: 0.8381
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4342 - accuracy: 0.8508
# ====================================================
#       Reference Window 6 Detection Window 7
#       Min. Adjacency: 0.5428571428571429 After: 10% in Detection
#       Complete Result: [0.5428571428571429]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.5770 - accuracy: 0.8514
# 46/46 [==============================] - 1s 7ms/step - loss: 0.5034 - accuracy: 0.8588
# ====================================================
#       Reference Window 7 Detection Window 8
#       Min. Adjacency: 0.6486486486486487 After: 10% in Detection
#       Complete Result: [0.6486486486486487]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4039 - accuracy: 0.8541
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4710 - accuracy: 0.8572
# ====================================================
#       Reference Window 8 Detection Window 9
#       Min. Adjacency: 0.6428571428571428 After: 10% in Detection
#       Complete Result: [0.6428571428571428]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4310 - accuracy: 0.8723
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4260 - accuracy: 0.8648
# ====================================================
#       Reference Window 9 Detection Window 10
#       Min. Adjacency: 0.6875 After: 10% in Detection
#       Complete Result: [0.6875]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.5299 - accuracy: 0.8580
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4276 - accuracy: 0.8700
# ====================================================
#       Reference Window 10 Detection Window 11
#       Min. Adjacency: 0.7096774193548387 After: 10% in Detection
#       Complete Result: [0.7096774193548387]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4886 - accuracy: 0.8635
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4321 - accuracy: 0.8564
# ====================================================
#       Reference Window 11 Detection Window 12
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4663 - accuracy: 0.8653
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4406 - accuracy: 0.8644
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4287 - accuracy: 0.8539
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4272 - accuracy: 0.8489
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4839 - accuracy: 0.8646
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4695 - accuracy: 0.8660
# ====================================================
#       Reference Window 12 Detection Window 13
#       Min. Adjacency: 0.6129032258064516 After: 30% in Detection
#       Complete Result: [0.8461538461538461, 0.9583333333333334, 0.6129032258064516]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4880 - accuracy: 0.8642
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4618 - accuracy: 0.8598
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4713 - accuracy: 0.8635
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4458 - accuracy: 0.8634
# ====================================================
#       Reference Window 13 Detection Window 14
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.84, 0.6206896551724138]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4315 - accuracy: 0.8652
# 45/45 [==============================] - 1s 7ms/step - loss: 0.5147 - accuracy: 0.8400
# ====================================================
#       Reference Window 14 Detection Window 15
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.5244 - accuracy: 0.8716
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4952 - accuracy: 0.8673
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4802 - accuracy: 0.8708
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4603 - accuracy: 0.8693
# ====================================================
#       Reference Window 15 Detection Window 16
#       Min. Adjacency: 0.7407407407407407 After: 20% in Detection
#       Complete Result: [1.0, 0.7407407407407407]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.5152 - accuracy: 0.8736
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4607 - accuracy: 0.8606
# ====================================================
#       Reference Window 16 Detection Window 17
#       Min. Adjacency: 0.5833333333333333 After: 10% in Detection
#       Complete Result: [0.5833333333333333]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4685 - accuracy: 0.8554
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4600 - accuracy: 0.8670
# ====================================================
#       Reference Window 17 Detection Window 18
#       Min. Adjacency: 0.6129032258064516 After: 10% in Detection
#       Complete Result: [0.6129032258064516]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4480 - accuracy: 0.8633
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4235 - accuracy: 0.8499
# ====================================================
#       Reference Window 18 Detection Window 19
#       Min. Adjacency: 0.6363636363636364 After: 10% in Detection
#       Complete Result: [0.6363636363636364]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4763 - accuracy: 0.8608
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4320 - accuracy: 0.8660
# ====================================================
#       Reference Window 19 Detection Window 20
#       Min. Adjacency: 0.6060606060606061 After: 10% in Detection
#       Complete Result: [0.6060606060606061]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4509 - accuracy: 0.8738
# 47/47 [==============================] - 1s 6ms/step - loss: 0.3778 - accuracy: 0.8756
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4052 - accuracy: 0.8681
# 46/46 [==============================] - 1s 7ms/step - loss: 0.3962 - accuracy: 0.8607
# ====================================================
#       Reference Window 20 Detection Window 21
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.8571428571428572, 0.6206896551724138]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.5077 - accuracy: 0.8625
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4328 - accuracy: 0.8709
# ====================================================
#       Reference Window 21 Detection Window 22
#       Min. Adjacency: 0.7931034482758621 After: 10% in Detection
#       Complete Result: [0.7931034482758621]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.5759 - accuracy: 0.8497
# 45/45 [==============================] - 1s 7ms/step - loss: 0.5670 - accuracy: 0.8585
# ====================================================
#       Reference Window 22 Detection Window 23
#       Min. Adjacency: 0.6111111111111112 After: 10% in Detection
#       Complete Result: [0.6111111111111112]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.5081 - accuracy: 0.8567
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4640 - accuracy: 0.8692
# ====================================================
#       Reference Window 23 Detection Window 24
#       Min. Adjacency: 0.76 After: 10% in Detection
#       Complete Result: [0.76]
#
# 41/41 [==============================] - 1s 6ms/step - loss: 0.5409 - accuracy: 0.8450
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4355 - accuracy: 0.8803
# ====================================================
#       Reference Window 24 Detection Window 25
#       Min. Adjacency: 0.5 After: 10% in Detection
#       Complete Result: [0.5]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4002 - accuracy: 0.8708
# 47/47 [==============================] - 1s 7ms/step - loss: 0.3830 - accuracy: 0.8771
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4287 - accuracy: 0.8680
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4289 - accuracy: 0.8657
# ====================================================
#       Reference Window 25 Detection Window 26
#       Min. Adjacency: 0.7777777777777778 After: 20% in Detection
#       Complete Result: [0.9259259259259259, 0.7777777777777778]
#
# 41/41 [==============================] - 1s 6ms/step - loss: 0.6368 - accuracy: 0.8582
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4895 - accuracy: 0.8572
# ====================================================
#       Reference Window 26 Detection Window 27
#       Min. Adjacency: 0.6333333333333333 After: 10% in Detection
#       Complete Result: [0.6333333333333333]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4627 - accuracy: 0.8597
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4125 - accuracy: 0.8538
# ====================================================
#       Reference Window 27 Detection Window 28
#       Min. Adjacency: 0.5294117647058824 After: 10% in Detection
#       Complete Result: [0.5294117647058824]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4343 - accuracy: 0.8571
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4556 - accuracy: 0.8552
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4417 - accuracy: 0.8484
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4681 - accuracy: 0.8664
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4673 - accuracy: 0.8528
# 46/46 [==============================] - 1s 6ms/step - loss: 0.3881 - accuracy: 0.8634
# ====================================================
#       Reference Window 28 Detection Window 29
#       Min. Adjacency: 0.75 After: 30% in Detection
#       Complete Result: [0.8333333333333334, 0.8148148148148149, 0.75]
#
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4530 - accuracy: 0.8728
# 46/46 [==============================] - 1s 7ms/step - loss: 0.5150 - accuracy: 0.8523
# ====================================================
#       Reference Window 29 Detection Window 30
#       Min. Adjacency: 0.7241379310344828 After: 10% in Detection
#       Complete Result: [0.7241379310344828]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4907 - accuracy: 0.8511
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4079 - accuracy: 0.8512
# ====================================================
#       Reference Window 30 Detection Window 31
#       Min. Adjacency: 0.7142857142857143 After: 10% in Detection
#       Complete Result: [0.7142857142857143]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4570 - accuracy: 0.8500
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4187 - accuracy: 0.8604
# ====================================================
#       Reference Window 31 Detection Window 32
#       Min. Adjacency: 0.5483870967741935 After: 10% in Detection
#       Complete Result: [0.5483870967741935]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4938 - accuracy: 0.8673
# 46/46 [==============================] - 1s 6ms/step - loss: 0.3796 - accuracy: 0.8587
# ====================================================
#       Reference Window 32 Detection Window 33
#       Min. Adjacency: 0.7407407407407407 After: 10% in Detection
#       Complete Result: [0.7407407407407407]
#
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4541 - accuracy: 0.8669
# 47/47 [==============================] - 1s 6ms/step - loss: 0.4222 - accuracy: 0.8660
# ====================================================
#       Reference Window 33 Detection Window 34
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4575 - accuracy: 0.8674
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4328 - accuracy: 0.8459
# ====================================================
#       Reference Window 34 Detection Window 35
#       Min. Adjacency: 0.5151515151515151 After: 10% in Detection
#       Complete Result: [0.5151515151515151]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4839 - accuracy: 0.8459
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4328 - accuracy: 0.8666
# ====================================================
#       Reference Window 35 Detection Window 36
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#
# 45/45 [==============================] - 1s 6ms/step - loss: 0.3934 - accuracy: 0.8715
# 47/47 [==============================] - 1s 7ms/step - loss: 0.4011 - accuracy: 0.8747
# ====================================================
#       Reference Window 36 Detection Window 37
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.6112 - accuracy: 0.8316
# 44/44 [==============================] - 1s 6ms/step - loss: 0.5273 - accuracy: 0.8613
# ====================================================
#       Reference Window 37 Detection Window 38
#       Min. Adjacency: 0.5555555555555556 After: 10% in Detection
#       Complete Result: [0.5555555555555556]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4110 - accuracy: 0.8571
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4204 - accuracy: 0.8708
# ====================================================
#       Reference Window 38 Detection Window 39
#       Min. Adjacency: 0.53125 After: 10% in Detection
#       Complete Result: [0.53125]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4339 - accuracy: 0.8615
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4451 - accuracy: 0.8539
# ====================================================
#       Reference Window 39 Detection Window 40
#       Min. Adjacency: 0.5714285714285714 After: 10% in Detection
#       Complete Result: [0.5714285714285714]
#
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4390 - accuracy: 0.8518
# 47/47 [==============================] - 1s 6ms/step - loss: 0.3974 - accuracy: 0.8655
# ====================================================
#       Reference Window 40 Detection Window 41
#       Min. Adjacency: 0.65625 After: 10% in Detection
#       Complete Result: [0.65625]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4384 - accuracy: 0.8690
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4396 - accuracy: 0.8685
# ====================================================
#       Reference Window 41 Detection Window 42
#       Min. Adjacency: 0.7741935483870968 After: 10% in Detection
#       Complete Result: [0.7741935483870968]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4488 - accuracy: 0.8702
# 47/47 [==============================] - 1s 6ms/step - loss: 0.4159 - accuracy: 0.8503
# ====================================================
#       Reference Window 42 Detection Window 43
#       Min. Adjacency: 0.5428571428571429 After: 10% in Detection
#       Complete Result: [0.5428571428571429]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4491 - accuracy: 0.8615
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4520 - accuracy: 0.8620
# ====================================================
#       Reference Window 43 Detection Window 44
#       Min. Adjacency: 0.5806451612903225 After: 10% in Detection
#       Complete Result: [0.5806451612903225]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4683 - accuracy: 0.8480
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4712 - accuracy: 0.8535
# ====================================================
#       Reference Window 44 Detection Window 45
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4460 - accuracy: 0.8565
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4399 - accuracy: 0.8473
# ====================================================
#       Reference Window 45 Detection Window 46
#       Min. Adjacency: 0.6666666666666667 After: 10% in Detection
#       Complete Result: [0.6666666666666667]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4619 - accuracy: 0.8363
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4484 - accuracy: 0.8542
# ====================================================
#       Reference Window 46 Detection Window 47
#       Min. Adjacency: 0.5357142857142857 After: 10% in Detection
#       Complete Result: [0.5357142857142857]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4698 - accuracy: 0.8467
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4645 - accuracy: 0.8486
# ====================================================
#       Reference Window 47 Detection Window 48
#       Min. Adjacency: 0.7916666666666666 After: 10% in Detection
#       Complete Result: [0.7916666666666666]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4575 - accuracy: 0.8631
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4067 - accuracy: 0.8595
# ====================================================
#       Reference Window 48 Detection Window 49
#       Min. Adjacency: 0.5714285714285714 After: 10% in Detection
#       Complete Result: [0.5714285714285714]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4682 - accuracy: 0.8447
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4734 - accuracy: 0.8553
# ====================================================
#       Reference Window 49 Detection Window 50
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4291 - accuracy: 0.8648
# 47/47 [==============================] - 1s 7ms/step - loss: 0.3968 - accuracy: 0.8628
# ====================================================
#       Reference Window 50 Detection Window 51
#       Min. Adjacency: 0.6923076923076923 After: 10% in Detection
#       Complete Result: [0.6923076923076923]
#
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4498 - accuracy: 0.8737
# 47/47 [==============================] - 1s 6ms/step - loss: 0.4018 - accuracy: 0.8747
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4463 - accuracy: 0.8626
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4247 - accuracy: 0.8674
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4640 - accuracy: 0.8737
# 46/46 [==============================] - 1s 7ms/step - loss: 0.3957 - accuracy: 0.8632
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4255 - accuracy: 0.8577
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4219 - accuracy: 0.8742
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4819 - accuracy: 0.8647
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4272 - accuracy: 0.8562
# ====================================================
#       Reference Window 51 Detection Window 52
#       Min. Adjacency: 0.5 After: 50% in Detection
#       Complete Result: [0.9615384615384616, 0.8148148148148149, 0.92, 0.88, 0.5]
#
# 43/43 [==============================] - 1s 6ms/step - loss: 0.5593 - accuracy: 0.8438
# 44/44 [==============================] - 1s 7ms/step - loss: 0.5902 - accuracy: 0.8428
# ====================================================
#       Reference Window 52 Detection Window 53
#       Min. Adjacency: 0.5526315789473684 After: 10% in Detection
#       Complete Result: [0.5526315789473684]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.5341 - accuracy: 0.8624
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4807 - accuracy: 0.8696
# ====================================================
#       Reference Window 53 Detection Window 54
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#
# 44/44 [==============================] - 1s 6ms/step - loss: 0.3866 - accuracy: 0.8526
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4146 - accuracy: 0.8556
# ====================================================
#       Reference Window 54 Detection Window 55
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#
# 41/41 [==============================] - 1s 6ms/step - loss: 0.5509 - accuracy: 0.8682
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4814 - accuracy: 0.8644
# ====================================================
#       Reference Window 55 Detection Window 56
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4615 - accuracy: 0.8644
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4414 - accuracy: 0.8753
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4770 - accuracy: 0.8592
# 44/44 [==============================] - 1s 7ms/step - loss: 0.3763 - accuracy: 0.8777
# ====================================================
#       Reference Window 56 Detection Window 57
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.8620689655172413, 0.6206896551724138]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4403 - accuracy: 0.8635
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4600 - accuracy: 0.8650
# ====================================================
#       Reference Window 57 Detection Window 58
#       Min. Adjacency: 0.7352941176470589 After: 10% in Detection
#       Complete Result: [0.7352941176470589]
#
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4130 - accuracy: 0.8573
# 46/46 [==============================] - 1s 6ms/step - loss: 0.3921 - accuracy: 0.8494
# ====================================================
#       Reference Window 58 Detection Window 59
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4461 - accuracy: 0.8505
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4785 - accuracy: 0.8482
# ====================================================
#       Reference Window 59 Detection Window 60
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4281 - accuracy: 0.8725
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4051 - accuracy: 0.8689
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4488 - accuracy: 0.8660
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4130 - accuracy: 0.8674
# ====================================================
#       Reference Window 60 Detection Window 61
#       Min. Adjacency: 0.7857142857142857 After: 20% in Detection
#       Complete Result: [0.9230769230769231, 0.7857142857142857]
#
# 42/42 [==============================] - 1s 7ms/step - loss: 0.4744 - accuracy: 0.8631
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4700 - accuracy: 0.8615
# 42/42 [==============================] - 1s 6ms/step - loss: 0.5612 - accuracy: 0.8247
# 45/45 [==============================] - 1s 7ms/step - loss: 0.3976 - accuracy: 0.8583
# ====================================================
#       Reference Window 61 Detection Window 62
#       Min. Adjacency: 0.75 After: 20% in Detection
#       Complete Result: [0.8888888888888888, 0.75]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4147 - accuracy: 0.8710
# 46/46 [==============================] - 1s 7ms/step - loss: 0.3921 - accuracy: 0.8702
# ====================================================
#       Reference Window 62 Detection Window 63
#       Min. Adjacency: 0.7857142857142857 After: 10% in Detection
#       Complete Result: [0.7857142857142857]
#
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4679 - accuracy: 0.8692
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4265 - accuracy: 0.8698
# ====================================================
#       Reference Window 63 Detection Window 64
#       Min. Adjacency: 0.7666666666666666 After: 10% in Detection
#       Complete Result: [0.7666666666666666]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4472 - accuracy: 0.8471
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4908 - accuracy: 0.8573
# ====================================================
#       Reference Window 64 Detection Window 65
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4380 - accuracy: 0.8731
# 45/45 [==============================] - 1s 6ms/step - loss: 0.4220 - accuracy: 0.8492
# ====================================================
#       Reference Window 65 Detection Window 66
#       Min. Adjacency: 0.3529411764705882 After: 10% in Detection
#       Complete Result: [0.3529411764705882]
#
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4444 - accuracy: 0.8662
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4410 - accuracy: 0.8527
# ====================================================
#       Reference Window 66 Detection Window 67
#       Min. Adjacency: 0.5151515151515151 After: 10% in Detection
#       Complete Result: [0.5151515151515151]
#
# 41/41 [==============================] - 1s 6ms/step - loss: 0.6039 - accuracy: 0.8289
# 43/43 [==============================] - 1s 7ms/step - loss: 0.5763 - accuracy: 0.8538
# ====================================================
#       Reference Window 67 Detection Window 68
#       Min. Adjacency: 0.7241379310344828 After: 10% in Detection
#       Complete Result: [0.7241379310344828]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4581 - accuracy: 0.8376
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4887 - accuracy: 0.8560
# ====================================================
#       Reference Window 68 Detection Window 69
#       Min. Adjacency: 0.6923076923076923 After: 10% in Detection
#       Complete Result: [0.6923076923076923]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.5374 - accuracy: 0.8588
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4907 - accuracy: 0.8506
# ====================================================
#       Reference Window 69 Detection Window 70
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.5168 - accuracy: 0.8746
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4114 - accuracy: 0.8537
# ====================================================
#       Reference Window 70 Detection Window 71
#       Min. Adjacency: 0.6666666666666667 After: 10% in Detection
#       Complete Result: [0.6666666666666667]
#
# 43/43 [==============================] - 1s 7ms/step - loss: 0.4457 - accuracy: 0.8721
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4063 - accuracy: 0.8482
# ====================================================
#       Reference Window 71 Detection Window 72
#       Min. Adjacency: 0.6428571428571428 After: 10% in Detection
#       Complete Result: [0.6428571428571428]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4589 - accuracy: 0.8548
# 46/46 [==============================] - 1s 7ms/step - loss: 0.4275 - accuracy: 0.8669
# ====================================================
#       Reference Window 72 Detection Window 73
#       Min. Adjacency: 0.7692307692307692 After: 10% in Detection
#       Complete Result: [0.7692307692307692]
#
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4339 - accuracy: 0.8606
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4011 - accuracy: 0.8721
# 44/44 [==============================] - 1s 6ms/step - loss: 0.4525 - accuracy: 0.8453
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4449 - accuracy: 0.8554
# 44/44 [==============================] - 1s 7ms/step - loss: 0.4864 - accuracy: 0.8700
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4448 - accuracy: 0.8540
# 44/44 [==============================] - 1s 7ms/step - loss: 0.5217 - accuracy: 0.8598
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4590 - accuracy: 0.8608
# ====================================================
#       Reference Window 73 Detection Window 74
#       Min. Adjacency: 0.6666666666666667 After: 40% in Detection
#       Complete Result: [0.8461538461538461, 0.8518518518518519, 0.8571428571428572, 0.6666666666666667]
#
# 45/45 [==============================] - 1s 8ms/step - loss: 0.4077 - accuracy: 0.8718
# 45/45 [==============================] - 1s 7ms/step - loss: 0.4921 - accuracy: 0.8479
# ====================================================
#       Reference Window 74 Detection Window 0
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#
# ====================================================
#       Reference Window 0 Detection Window 1
#       Min. Adjacency: 0.75 After: 10% in Detection
#       Complete Result: [0.75]
#       ====================================================
#       Reference Window 1 Detection Window 2
#       Min. Adjacency: 0.5666666666666667 After: 10% in Detection
#       Complete Result: [0.5666666666666667]
#       ====================================================
#       Reference Window 2 Detection Window 3
#       Min. Adjacency: 0.46875 After: 10% in Detection
#       Complete Result: [0.46875]
#       ====================================================
#       Reference Window 3 Detection Window 4
#       Min. Adjacency: 0.6666666666666667 After: 30% in Detection
#       Complete Result: [0.8461538461538461, 0.92, 0.6666666666666667]
#       ====================================================
#       Reference Window 4 Detection Window 5
#       Min. Adjacency: 0.6875 After: 10% in Detection
#       Complete Result: [0.6875]
#       ====================================================
#       Reference Window 5 Detection Window 6
#       Min. Adjacency: 0.5555555555555556 After: 10% in Detection
#       Complete Result: [0.5555555555555556]
#       ====================================================
#       Reference Window 6 Detection Window 7
#       Min. Adjacency: 0.5428571428571429 After: 10% in Detection
#       Complete Result: [0.5428571428571429]
#       ====================================================
#       Reference Window 7 Detection Window 8
#       Min. Adjacency: 0.6486486486486487 After: 10% in Detection
#       Complete Result: [0.6486486486486487]
#       ====================================================
#       Reference Window 8 Detection Window 9
#       Min. Adjacency: 0.6428571428571428 After: 10% in Detection
#       Complete Result: [0.6428571428571428]
#       ====================================================
#       Reference Window 9 Detection Window 10
#       Min. Adjacency: 0.6875 After: 10% in Detection
#       Complete Result: [0.6875]
#       ====================================================
#       Reference Window 10 Detection Window 11
#       Min. Adjacency: 0.7096774193548387 After: 10% in Detection
#       Complete Result: [0.7096774193548387]
#       ====================================================
#       Reference Window 11 Detection Window 12
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#       ====================================================
#       Reference Window 12 Detection Window 13
#       Min. Adjacency: 0.6129032258064516 After: 30% in Detection
#       Complete Result: [0.8461538461538461, 0.9583333333333334, 0.6129032258064516]
#       ====================================================
#       Reference Window 13 Detection Window 14
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.84, 0.6206896551724138]
#       ====================================================
#       Reference Window 14 Detection Window 15
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#       ====================================================
#       Reference Window 15 Detection Window 16
#       Min. Adjacency: 0.7407407407407407 After: 20% in Detection
#       Complete Result: [1.0, 0.7407407407407407]
#       ====================================================
#       Reference Window 16 Detection Window 17
#       Min. Adjacency: 0.5833333333333333 After: 10% in Detection
#       Complete Result: [0.5833333333333333]
#       ====================================================
#       Reference Window 17 Detection Window 18
#       Min. Adjacency: 0.6129032258064516 After: 10% in Detection
#       Complete Result: [0.6129032258064516]
#       ====================================================
#       Reference Window 18 Detection Window 19
#       Min. Adjacency: 0.6363636363636364 After: 10% in Detection
#       Complete Result: [0.6363636363636364]
#       ====================================================
#       Reference Window 19 Detection Window 20
#       Min. Adjacency: 0.6060606060606061 After: 10% in Detection
#       Complete Result: [0.6060606060606061]
#       ====================================================
#       Reference Window 20 Detection Window 21
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.8571428571428572, 0.6206896551724138]
#       ====================================================
#       Reference Window 21 Detection Window 22
#       Min. Adjacency: 0.7931034482758621 After: 10% in Detection
#       Complete Result: [0.7931034482758621]
#       ====================================================
#       Reference Window 22 Detection Window 23
#       Min. Adjacency: 0.6111111111111112 After: 10% in Detection
#       Complete Result: [0.6111111111111112]
#       ====================================================
#       Reference Window 23 Detection Window 24
#       Min. Adjacency: 0.76 After: 10% in Detection
#       Complete Result: [0.76]
#       ====================================================
#       Reference Window 24 Detection Window 25
#       Min. Adjacency: 0.5 After: 10% in Detection
#       Complete Result: [0.5]
#       ====================================================
#       Reference Window 25 Detection Window 26
#       Min. Adjacency: 0.7777777777777778 After: 20% in Detection
#       Complete Result: [0.9259259259259259, 0.7777777777777778]
#       ====================================================
#       Reference Window 26 Detection Window 27
#       Min. Adjacency: 0.6333333333333333 After: 10% in Detection
#       Complete Result: [0.6333333333333333]
#       ====================================================
#       Reference Window 27 Detection Window 28
#       Min. Adjacency: 0.5294117647058824 After: 10% in Detection
#       Complete Result: [0.5294117647058824]
#       ====================================================
#       Reference Window 28 Detection Window 29
#       Min. Adjacency: 0.75 After: 30% in Detection
#       Complete Result: [0.8333333333333334, 0.8148148148148149, 0.75]
#       ====================================================
#       Reference Window 29 Detection Window 30
#       Min. Adjacency: 0.7241379310344828 After: 10% in Detection
#       Complete Result: [0.7241379310344828]
#       ====================================================
#       Reference Window 30 Detection Window 31
#       Min. Adjacency: 0.7142857142857143 After: 10% in Detection
#       Complete Result: [0.7142857142857143]
#       ====================================================
#       Reference Window 31 Detection Window 32
#       Min. Adjacency: 0.5483870967741935 After: 10% in Detection
#       Complete Result: [0.5483870967741935]
#       ====================================================
#       Reference Window 32 Detection Window 33
#       Min. Adjacency: 0.7407407407407407 After: 10% in Detection
#       Complete Result: [0.7407407407407407]
#       ====================================================
#       Reference Window 33 Detection Window 34
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#       ====================================================
#       Reference Window 34 Detection Window 35
#       Min. Adjacency: 0.5151515151515151 After: 10% in Detection
#       Complete Result: [0.5151515151515151]
#       ====================================================
#       Reference Window 35 Detection Window 36
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#       ====================================================
#       Reference Window 36 Detection Window 37
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#       ====================================================
#       Reference Window 37 Detection Window 38
#       Min. Adjacency: 0.5555555555555556 After: 10% in Detection
#       Complete Result: [0.5555555555555556]
#       ====================================================
#       Reference Window 38 Detection Window 39
#       Min. Adjacency: 0.53125 After: 10% in Detection
#       Complete Result: [0.53125]
#       ====================================================
#       Reference Window 39 Detection Window 40
#       Min. Adjacency: 0.5714285714285714 After: 10% in Detection
#       Complete Result: [0.5714285714285714]
#       ====================================================
#       Reference Window 40 Detection Window 41
#       Min. Adjacency: 0.65625 After: 10% in Detection
#       Complete Result: [0.65625]
#       ====================================================
#       Reference Window 41 Detection Window 42
#       Min. Adjacency: 0.7741935483870968 After: 10% in Detection
#       Complete Result: [0.7741935483870968]
#       ====================================================
#       Reference Window 42 Detection Window 43
#       Min. Adjacency: 0.5428571428571429 After: 10% in Detection
#       Complete Result: [0.5428571428571429]
#       ====================================================
#       Reference Window 43 Detection Window 44
#       Min. Adjacency: 0.5806451612903225 After: 10% in Detection
#       Complete Result: [0.5806451612903225]
#       ====================================================
#       Reference Window 44 Detection Window 45
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#       ====================================================
#       Reference Window 45 Detection Window 46
#       Min. Adjacency: 0.6666666666666667 After: 10% in Detection
#       Complete Result: [0.6666666666666667]
#       ====================================================
#       Reference Window 46 Detection Window 47
#       Min. Adjacency: 0.5357142857142857 After: 10% in Detection
#       Complete Result: [0.5357142857142857]
#       ====================================================
#       Reference Window 47 Detection Window 48
#       Min. Adjacency: 0.7916666666666666 After: 10% in Detection
#       Complete Result: [0.7916666666666666]
#       ====================================================
#       Reference Window 48 Detection Window 49
#       Min. Adjacency: 0.5714285714285714 After: 10% in Detection
#       Complete Result: [0.5714285714285714]
#       ====================================================
#       Reference Window 49 Detection Window 50
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#       ====================================================
#       Reference Window 50 Detection Window 51
#       Min. Adjacency: 0.6923076923076923 After: 10% in Detection
#       Complete Result: [0.6923076923076923]
#       ====================================================
#       Reference Window 51 Detection Window 52
#       Min. Adjacency: 0.5 After: 50% in Detection
#       Complete Result: [0.9615384615384616, 0.8148148148148149, 0.92, 0.88, 0.5]
#       ====================================================
#       Reference Window 52 Detection Window 53
#       Min. Adjacency: 0.5526315789473684 After: 10% in Detection
#       Complete Result: [0.5526315789473684]
#       ====================================================
#       Reference Window 53 Detection Window 54
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#       ====================================================
#       Reference Window 54 Detection Window 55
#       Min. Adjacency: 0.6071428571428572 After: 10% in Detection
#       Complete Result: [0.6071428571428572]
#       ====================================================
#       Reference Window 55 Detection Window 56
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#       ====================================================
#       Reference Window 56 Detection Window 57
#       Min. Adjacency: 0.6206896551724138 After: 20% in Detection
#       Complete Result: [0.8620689655172413, 0.6206896551724138]
#       ====================================================
#       Reference Window 57 Detection Window 58
#       Min. Adjacency: 0.7352941176470589 After: 10% in Detection
#       Complete Result: [0.7352941176470589]
#       ====================================================
#       Reference Window 58 Detection Window 59
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#       ====================================================
#       Reference Window 59 Detection Window 60
#       Min. Adjacency: 0.7333333333333334 After: 10% in Detection
#       Complete Result: [0.7333333333333334]
#       ====================================================
#       Reference Window 60 Detection Window 61
#       Min. Adjacency: 0.7857142857142857 After: 20% in Detection
#       Complete Result: [0.9230769230769231, 0.7857142857142857]
#       ====================================================
#       Reference Window 61 Detection Window 62
#       Min. Adjacency: 0.75 After: 20% in Detection
#       Complete Result: [0.8888888888888888, 0.75]
#       ====================================================
#       Reference Window 62 Detection Window 63
#       Min. Adjacency: 0.7857142857142857 After: 10% in Detection
#       Complete Result: [0.7857142857142857]
#       ====================================================
#       Reference Window 63 Detection Window 64
#       Min. Adjacency: 0.7666666666666666 After: 10% in Detection
#       Complete Result: [0.7666666666666666]
#       ====================================================
#       Reference Window 64 Detection Window 65
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
#       ====================================================
#       Reference Window 65 Detection Window 66
#       Min. Adjacency: 0.3529411764705882 After: 10% in Detection
#       Complete Result: [0.3529411764705882]
#       ====================================================
#       Reference Window 66 Detection Window 67
#       Min. Adjacency: 0.5151515151515151 After: 10% in Detection
#       Complete Result: [0.5151515151515151]
#       ====================================================
#       Reference Window 67 Detection Window 68
#       Min. Adjacency: 0.7241379310344828 After: 10% in Detection
#       Complete Result: [0.7241379310344828]
#       ====================================================
#       Reference Window 68 Detection Window 69
#       Min. Adjacency: 0.6923076923076923 After: 10% in Detection
#       Complete Result: [0.6923076923076923]
#       ====================================================
#       Reference Window 69 Detection Window 70
#       Min. Adjacency: 0.5862068965517242 After: 10% in Detection
#       Complete Result: [0.5862068965517242]
#       ====================================================
#       Reference Window 70 Detection Window 71
#       Min. Adjacency: 0.6666666666666667 After: 10% in Detection
#       Complete Result: [0.6666666666666667]
#       ====================================================
#       Reference Window 71 Detection Window 72
#       Min. Adjacency: 0.6428571428571428 After: 10% in Detection
#       Complete Result: [0.6428571428571428]
#       ====================================================
#       Reference Window 72 Detection Window 73
#       Min. Adjacency: 0.7692307692307692 After: 10% in Detection
#       Complete Result: [0.7692307692307692]
#       ====================================================
#       Reference Window 73 Detection Window 74
#       Min. Adjacency: 0.6666666666666667 After: 40% in Detection
#       Complete Result: [0.8461538461538461, 0.8518518518518519, 0.8571428571428572, 0.6666666666666667]
#       ====================================================
#       Reference Window 74 Detection Window 0
#       Min. Adjacency: 0.6 After: 10% in Detection
#       Complete Result: [0.6]
